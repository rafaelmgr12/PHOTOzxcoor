# %% [markdown]
# v5

# %% [markdown]
# # Photometric Redshift Estimation

# %% [markdown]
# We will try to estimate the redshift from DES data using the match from the Vipers.
#
# We use Machine Learning methods and Deep learning methods

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False
if IN_COLAB:
    print("Baixando Funções que serão usadas nesse notebook")
    ! shred -u astroFunctions.py
    ! wget https://raw.githubusercontent.com/rafaelmgr12/PHOTOzxcorr/main/functions/ml_functions.py -O ml_functions.py
    ! wget
    ! pip install esutil
    ! pip install healpy
    import astroFunctions as astro
    from google.colab import drive
    drive.mount('/content/drive')
else:
    import sys,os
    home = os.getenv("HOME")
    sys.path.append(home+"/Projetos/PHOTOzxcorr/functions/") # user here the path where we download the folder DESzxcoorr

# %%
import logging 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import healpy as hp
import os,sys
import matplotlib
from astropy.io import ascii 
from astropy.table import Table
import seaborn as sns
import time

# Regression Libraries
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor,StackingRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.kernel_ridge import KernelRidge
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
import xgboost as xgb
import lightgbm as lgb
from tensorflow.keras import layers
from tensorflow.keras import regularizers


# Other Libraries
from sklearn.decomposition import PCA
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler,RobustScaler
import category_encoders as ce
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import cross_val_score, KFold, train_test_split,ShuffleSplit
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.metrics import mean_squared_error
from scipy import stats
from scipy.stats import norm, skew #for some statistics


# Neural Network Libs
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, BatchNormalization,Activation
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras import backend as K
from sklearn.metrics import confusion_matrix
import keras as ks
# %matplotlib inline

# %%
def clean_tab(tab,col,val):
    tab.drop(tab[tab[col]==val].index,inplace = True)
def tts_split(X,y,size):
    rs = ShuffleSplit(n_splits=5, test_size=size)
    rs.get_n_splits(X)
    for train_index, test_index in rs.split(X, y): 
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
    return X_train, X_test,y_train, y_test

n_folds = 5

def rmsle_cv(model,X_train,y_train):
    kf = KFold(3, shuffle=True, random_state=None).get_n_splits(X_train)
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train.ravel(), scoring="neg_mean_squared_error", cv = kf))
    return(rmse)
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))
def rmse_ann(y_true, y_pred):
    return ks.backend.sqrt(ks.backend.mean(ks.backend.square(y_pred - y_true), axis=-1))
def rmse_ann2(y_true, y_pred):
    return ks.backend.sqrt(ks.backend.mean(ks.backend.square(y_pred - y_true), axis=-1))
def rmse_ann3(y_true, y_pred):
    return ks.backend.sqrt(ks.backend.mean(ks.backend.square(y_pred - y_true), axis=-1))
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [MPG]')
    plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
    plt.ylim([0,1])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$MPG^2$]')
    plt.plot(hist['epoch'], hist['mse'],
               label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'],
               label = 'Val Error')
    plt.ylim([0,1])
    plt.legend()
    plt.show()
# Mostra o progresso do treinamento imprimindo um único ponto para cada epoch completada
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

def get_features_targets(data):
    features = np.zeros(shape=(len(data), 4))
    
    features[:, 0] = data['MAG_AUTO_G'] - data['MAG_AUTO_R']
    features[:, 1] = data['MAG_AUTO_R'] - data['MAG_AUTO_I']
    features[:, 2] = data['MAG_AUTO_I'] - data['MAG_AUTO_Z']
    features[:, 3] = data['MAG_AUTO_Z'] - data['MAG_AUTO_Y']
    #features[:, 4] = data['WAVG_MAG_PSF_G'] - data['WAVG_MAG_PSF_R']
    #features[:, 5] = data['WAVG_MAG_PSF_R'] - data['WAVG_MAG_PSF_I']
    #features[:, 6] = data['WAVG_MAG_PSF_I'] - data['WAVG_MAG_PSF_Z']
    #features[:, 7] = data['WAVG_MAG_PSF_Z'] - data['WAVG_MAG_PSF_Y']

    
    
    targets = data['z']
    return features, targets

def get_features_targets2(data):
    features = np.zeros(shape=(len(data), 4))
    
    features[:, 0] = data['MAG_AUTO_G_DERED'] - data['MAG_AUTO_R_DERED']
    features[:, 1] = data['MAG_AUTO_R_DERED'] - data['MAG_AUTO_I_DERED']
    features[:, 2] = data['MAG_AUTO_I_DERED'] - data['MAG_AUTO_Z_DERED']
    features[:, 3] = data['MAG_AUTO_Z_DERED'] - data['MAG_AUTO_Y_DERED']
    #features[:, 4] = data['WAVG_MAG_PSF_G_DERED'] - data['WAVG_MAG_PSF_R_DERED']
    #features[:, 5] = data['WAVG_MAG_PSF_R_DERED'] - data['WAVG_MAG_PSF_I_DERED']
    #features[:, 6] = data['WAVG_MAG_PSF_I_DERED'] - data['WAVG_MAG_PSF_Z_DERED']
    #features[:, 7] = data['WAVG_MAG_PSF_Z_DERED'] - data['WAVG_MAG_PSF_Y_DERED']

    
    
    targets = data['z']
    return features, targets

# %%
if IN_COLAB:
    path1 = "/content/drive/Shareddrives/Optical Data/DES Data/match-des-ps2"
    path2 = "/content/drive/Shareddrives/Optical Data/DES Data/results/PSPixelFit_PS1_VIPERS_VVDS"
    path3 = "/content/drive/Shareddrives/Optical Data/DES Data/64"
else:
    path1 = home+"/Projetos/PHOTOzxcorr/data/des_vvds"
    path2 = home+"/Projetos/PHOTOzxcorr/data/vvds.fits"
    path3 = home+"/Projetos/PHOTOzxcorr/data/OzDES_GRC_2018_12_07.fits"

# %%
filename1 = os.listdir(path1)
#filename2 = os.listdir(path2)
#filename3 = os.listdir(path3)

# %%
vvds = Table.read(path2).to_pandas()
tab = Table.read(path3).to_pandas()

# %%
l1 = []
for i in range(len(filename1)): # if breaks, its the RAM so read less data.
    path_dir = os.path.join(path1,filename1[i])
    df = Table.read(path_dir).to_pandas()
    l1.append(df)
des = pd.concat(l1, axis=0, ignore_index=True)
del df,l1

# %%
tab.head()
# Out:
#                                   ID         RA        DEC       z  z_Err  \
# 0  b'APMUKS(BJ) B033420.07-271928.1'  54.108429 -27.159910  0.2440 -9.999
# 1  b'APMUKS(BJ) B033411.69-271617.8'  54.073959 -27.106859  0.1015 -9.999
# 2  b'GALEX J033649.0-271938        '  54.204361 -27.327370  0.1458 -9.999
# 3  b'[ECD2009] J053.96796-27.00658 '  53.967960 -27.006580  0.9389 -9.999
# 4  b'GALEXASC J033629.56-272329.8  '  54.123421 -27.391560  0.3502 -9.999
#
#       flag  source comments  totobs  totexp
# 0  b'    '  b'NED'     b'-'      -9      -9
# 1  b'    '  b'NED'     b'-'      -9      -9
# 2  b'    '  b'NED'     b'-'      -9      -9
# 3  b':   '  b'NED'     b'-'      -9      -9
# 4  b'    '  b'NED'     b'-'      -9      -9

# %%
vvds.head()
# Out:
#              ID       RA_1     DEC_1      z  z_Err  flag        source  \
# 0  b'020095413'  36.554878 -4.800845  0.871 -9.999  b'3'  b'VVDS_DEEP'
# 1  b'020091652'  36.567375 -4.811272  0.382 -9.999  b'3'  b'VVDS_DEEP'
# 2  b'020090930'  36.537343 -4.813442  0.266 -9.999  b'4'  b'VVDS_DEEP'
# 3  b'020087832'  36.518992 -4.819152  0.244 -9.999  b'4'  b'VVDS_DEEP'
# 4  b'020088050'  36.596351 -4.817919  0.519 -9.999  b'4'  b'VVDS_DEEP'
#
#   comments  totobs  totexp  ...  SPREADERR_MODEL_R SPREADERR_MODEL_I  \
# 0     b'-'      -9      -9  ...           0.001221          0.001351
# 1     b'-'      -9      -9  ...           0.001045          0.000933
# 2     b'-'      -9      -9  ...           0.000733          0.001063
# 3     b'-'      -9      -9  ...           0.000934          0.001672
# 4     b'-'      -9      -9  ...           0.000708          0.000680
#
#    SPREADERR_MODEL_Z  SPREADERR_MODEL_Y  WAVG_SPREADERR_MODEL_G  \
# 0           0.001825           0.007033                0.075774
# 1           0.001148           0.004134                0.003761
# 2           0.001801           0.005727                0.001133
# 3           0.003042           0.008880                0.001366
# 4           0.000949           0.003293                0.002572
#
#    WAVG_SPREADERR_MODEL_R  WAVG_SPREADERR_MODEL_I  WAVG_SPREADERR_MODEL_Z  \
# 0                0.001306                0.001532                0.001939
# 1                0.001091                0.000989                0.001242
# 2                0.000771                0.001113                0.001759
# 3                0.000995                0.001808                0.003627
# 4                0.000740                0.000726                0.000920
#
#    WAVG_SPREADERR_MODEL_Y    random
# 0              -99.000000  0.510718
# 1                0.004153  0.424861
# 2              -99.000000  0.140826
# 3              -99.000000  0.973567
# 4                0.002905  0.914822
#
# [5 rows x 224 columns]

# %%
des.head()
# Out:
#    COADD_OBJECT_ID         TILENAME  HPIX_32  HPIX_64  HPIX_1024  HPIX_4096  \
# 0        104665233  b'DES0219-0541'     4422    17689    4528640   72458240
# 1        110140506  b'DES0221-0416'     4422    17689    4528622   72457966
# 2        110141276  b'DES0221-0416'     4422    17689    4528622   72457962
# 3        110141600  b'DES0221-0416'     4422    17689    4528622   72457960
# 4        110142890  b'DES0221-0416'     4422    17689    4528619   72457914
#
#    HPIX_16384         RA       DEC  ALPHAWIN_J2000  ...  SPREADERR_MODEL_G  \
# 0  1159331840  34.452509 -5.376883       34.452509  ...           0.000934
# 1  1159327464  35.623279 -4.388962       35.623279  ...           0.012087
# 2  1159327404  35.608125 -4.404374       35.608125  ...           0.009313
# 3  1159327371  35.612266 -4.411218       35.612266  ...           0.006501
# 4  1159326638  35.560879 -4.440139       35.560879  ...           0.000440
#
#    SPREADERR_MODEL_R  SPREADERR_MODEL_I  SPREADERR_MODEL_Z  SPREADERR_MODEL_Y  \
# 0           0.000562           0.000566           0.000829           0.002365
# 1           0.003399           0.002264           0.002455           0.006365
# 2           0.006066           0.004834           0.006624           0.014340
# 3           0.003061           0.001976           0.002048           0.004460
# 4           0.001246           0.001589           0.002014           0.004566
#
#    WAVG_SPREADERR_MODEL_G  WAVG_SPREADERR_MODEL_R  WAVG_SPREADERR_MODEL_I  \
# 0                 0.00192                0.000748                0.001186
# 1               -99.00000              -99.000000                0.002392
# 2               -99.00000              -99.000000              -99.000000
# 3               -99.00000                0.006813                0.001997
# 4               -99.00000              -99.000000              -99.000000
#
#    WAVG_SPREADERR_MODEL_Z  WAVG_SPREADERR_MODEL_Y
# 0                0.001678                0.002032
# 1                0.002708              -99.000000
# 2              -99.000000              -99.000000
# 3                0.002202              -99.000000
# 4              -99.000000              -99.000000
#
# [5 rows x 213 columns]

# %%
originalTam = len(vvds)

# %% [markdown]
# **Counting the Galaxies of our Catalog**

# %%
pix = des['HPIX_1024'].unique()
pix_match = vvds["HPIX_1024"].unique()

# %%
pix = des['HPIX_1024'].unique()
pix_match = vvds["HPIX_1024"].unique()

num_des = []
avg_des = []
num_vvds = []
avg_vvds = []
for i in range(len(pix)):
    avg_des.append(des[des['HPIX_1024']==pix[i]]['MAG_AUTO_I'].mean())
    num_des.append(des[des['HPIX_1024']==pix[i]]['MAG_AUTO_I'].count())
for i in range(len(pix_match)):  
    avg_vvds.append(vvds[vvds['HPIX_1024']==pix_match[i]]['MAG_AUTO_I'].mean())
    num_vvds.append(vvds[vvds['HPIX_1024']==pix_match[i]]['MAG_AUTO_I'].count())

# %%
avg_des = np.asarray(avg_des)
num_des = np.asarray(num_des)

avg_vvds = np.asarray(avg_vvds)
num_vvds = np.asarray(num_vvds)

# %%
galaxies_des = pd.DataFrame(pix,columns=['HPIX_1024'])
galaxies_vvds = pd.DataFrame(pix_match,columns=['HPIX_1024'])
galaxies_des['AVG_des'] = avg_des
galaxies_des['COUNT_des'] = num_des
galaxies_vvds['AVG_vvds'] = avg_vvds
galaxies_vvds['COUNT_vvds'] = num_vvds

# %%
print("Galaxies in VVDSxDES match: ",galaxies_vvds['COUNT_vvds'].sum(),"\n Galaxies in Des",galaxies_des['COUNT_des'].sum())
# Out:
# Galaxies in VVDSxDES match:  2747
#  Galaxies in Des 163350

# %%
pix_des = galaxies_des.HPIX_1024.values
pix_vvds = galaxies_vvds.HPIX_1024.values

# %%
diff = np.setdiff1d(pix_des,pix_vvds)
diff
# Out:
# array([4526848, 4526849, 4526850, ..., 9205245, 9205246, 9205247])

# %%
num_des = []
avg_des = []
for i in range(len(pix_vvds)):
    avg_des.append(des[des['HPIX_1024']==pix_vvds[i]]['MAG_AUTO_I'].mean())
    num_des.append(des[des['HPIX_1024']==pix_vvds[i]]['MAG_AUTO_I'].count())

# %%
avg_des = np.asarray(avg_des)
num_des = np.asarray(num_des)

# %%
galaxies_desd = pd.DataFrame(pix_vvds,columns=['HPIX_1024'])
galaxies_desd['AVG_des'] = avg_des
galaxies_desd['COUNT_des'] = num_des

# %%
print("Galaxies contained in the DES catalogue",galaxies_desd['COUNT_des'].sum())
# Out:
# Galaxies contained in the DES catalogue 22636

# %%
print("Galaxies that are not contained in the match",galaxies_desd['COUNT_des'].sum()-galaxies_vvds["COUNT_vvds"].sum())
# Out:
# Galaxies that are not contained in the match 19889

# %%
print("We have {:f}% of the galaxie with the match".format(100*((galaxies_desd['COUNT_des'].sum()-galaxies_vvds["COUNT_vvds"].sum())/galaxies_desd['COUNT_des'].sum())))
# Out:
# We have 87.864464% of the galaxie with the match

# %%
vvds_orignal = tab[(tab['source']==b'VVDS_DEEP') | (tab['source']==b'VVDS_CDFS') ].copy()

# %%
print("Galaxies contained in the VVDS catalogue",len(vvds_orignal))
# Out:
# Galaxies contained in the VVDS catalogue 5295

# %%
print("Galaxies that are not contained in the match",len(vvds_orignal)-galaxies_vvds["COUNT_vvds"].sum())
# Out:
# Galaxies that are not contained in the match 2548

# %% [markdown]
# **Before the cleaning**

# %%
count1, n1 = np.histogram(des['MAG_AUTO_R'],bins = np.linspace(0,30,100))
count2, n2 = np.histogram(vvds['MAG_AUTO_R'],bins = np.linspace(0,30,100))

# %%
plt.figure(figsize=(12,10))
plt.bar(n2[:-1],(count2/count1))
plt.xlabel("Object in  MAG_AUTO_R")
#plt.ylim(0.8)
# Out:
# <ipython-input-29-9100a005af15>:2: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(n2[:-1],(count2/count1))
# Text(0.5, 0, 'Object in  MAG_AUTO_R')

# %% [markdown]
# ## Processing the data

# %%
vvds[vvds["MAG_AUTO_G_DERED"]>30]['MAG_AUTO_G_DERED']
# Out:
# 199     98.914841
# 415     98.918213
# 452     98.918373
# 479     98.917931
# 810     98.921021
# 1010    98.910828
# 1389    98.911942
# 1474    98.913246
# 1591    98.916046
# 1830    98.918694
# 2026    98.918945
# 2746    98.969383
# Name: MAG_AUTO_G_DERED, dtype: float64

# %%
vvds[vvds["WAVG_MAG_PSF_G_DERED"]>30]['WAVG_MAG_PSF_G_DERED']
# Out:
# 8       98.917389
# 10      98.917320
# 11      98.918663
# 15      98.917831
# 18      98.918022
#           ...
# 2728    98.968842
# 2734    98.971329
# 2738    98.969284
# 2744    98.971008
# 2746    98.969383
# Name: WAVG_MAG_PSF_G_DERED, Length: 1054, dtype: float64

# %%
len(vvds[vvds["MAG_AUTO_G_DERED"]>30]['MAG_AUTO_G_DERED'])
# Out:
# 12

# %%
len(vvds[vvds["WAVG_MAG_PSF_G_DERED"]>30]['WAVG_MAG_PSF_G_DERED'])
# Out:
# 1054

# %%
feat = ['MAG_AUTO_G','MAG_AUTO_R','MAG_AUTO_I','MAG_AUTO_Z','MAG_AUTO_Y',
        'MAG_AUTO_G_DERED','MAG_AUTO_R_DERED','MAG_AUTO_I_DERED','MAG_AUTO_Z_DERED','MAG_AUTO_Y_DERED',
        "WAVG_MAG_PSF_G","WAVG_MAG_PSF_R","WAVG_MAG_PSF_I","WAVG_MAG_PSF_Z","WAVG_MAG_PSF_Y"
       ,'WAVG_MAG_PSF_G_DERED','WAVG_MAG_PSF_R_DERED','WAVG_MAG_PSF_I_DERED','WAVG_MAG_PSF_Z_DERED','WAVG_MAG_PSF_Y_DERED']

# %%
vvds[(vvds[feat[0]]==99) | (vvds[feat[0]]==-99)][feat[0]]
# Out:
# 199     99.0
# 415     99.0
# 452     99.0
# 479     99.0
# 810     99.0
# 1010    99.0
# 1389    99.0
# 1474    99.0
# 1591    99.0
# 1830    99.0
# 2026    99.0
# 2746    99.0
# Name: MAG_AUTO_G, dtype: float64

# %%
for j in feat:
    print(j,":",len(vvds[(vvds[j]==99) | (vvds[j]==-99) |(vvds[j]>90)][j]),"\n")
# Out:
# MAG_AUTO_G : 12
#
# MAG_AUTO_R : 1
#
# MAG_AUTO_I : 1
#
# MAG_AUTO_Z : 4
#
# MAG_AUTO_Y : 128
#
# MAG_AUTO_G_DERED : 12
#
# MAG_AUTO_R_DERED : 1
#
# MAG_AUTO_I_DERED : 1
#
# MAG_AUTO_Z_DERED : 4
#
# MAG_AUTO_Y_DERED : 128
#
# WAVG_MAG_PSF_G : 1054
#
# WAVG_MAG_PSF_R : 361
#
# WAVG_MAG_PSF_I : 462
#
# WAVG_MAG_PSF_Z : 905
#
# WAVG_MAG_PSF_Y : 2194
#
# WAVG_MAG_PSF_G_DERED : 1054
#
# WAVG_MAG_PSF_R_DERED : 361
#
# WAVG_MAG_PSF_I_DERED : 462
#
# WAVG_MAG_PSF_Z_DERED : 905
#
# WAVG_MAG_PSF_Y_DERED : 2194

# %%
for i in feat:
    print(i," is ",100*len(vvds[(vvds[i]==99) | (vvds[i]==-99)|(vvds[i]>90)][j])/len(vvds),"%")
# Out:
# MAG_AUTO_G  is  0.43684018929741536 %
# MAG_AUTO_R  is  0.03640334910811795 %
# MAG_AUTO_I  is  0.03640334910811795 %
# MAG_AUTO_Z  is  0.1456133964324718 %
# MAG_AUTO_Y  is  4.659628685839097 %
# MAG_AUTO_G_DERED  is  0.43684018929741536 %
# MAG_AUTO_R_DERED  is  0.03640334910811795 %
# MAG_AUTO_I_DERED  is  0.03640334910811795 %
# MAG_AUTO_Z_DERED  is  0.1456133964324718 %
# MAG_AUTO_Y_DERED  is  4.659628685839097 %
# WAVG_MAG_PSF_G  is  38.36912995995632 %
# WAVG_MAG_PSF_R  is  13.14160902803058 %
# WAVG_MAG_PSF_I  is  16.81834728795049 %
# WAVG_MAG_PSF_Z  is  32.94503094284674 %
# WAVG_MAG_PSF_Y  is  79.86894794321077 %
# WAVG_MAG_PSF_G_DERED  is  38.36912995995632 %
# WAVG_MAG_PSF_R_DERED  is  13.14160902803058 %
# WAVG_MAG_PSF_I_DERED  is  16.81834728795049 %
# WAVG_MAG_PSF_Z_DERED  is  32.94503094284674 %
# WAVG_MAG_PSF_Y_DERED  is  79.86894794321077 %

# %%
vvds[vvds["WAVG_MAG_PSF_Y_DERED"]!=99]["WAVG_MAG_PSF_Y_DERED"].mean()
# Out:
# 83.15707304697277

# %%
vvds[vvds["WAVG_MAG_PSF_Y_DERED"]!=99]["WAVG_MAG_PSF_Y_DERED"].median()
# Out:
# 98.97205352783203

# %%
vvds[vvds["WAVG_MAG_PSF_Y_DERED"]!=99]["WAVG_MAG_PSF_Y_DERED"].std()
# Out:
# 31.51518700225641

# %%
vvds[vvds["WAVG_MAG_PSF_Y_DERED"]!=99]["WAVG_MAG_PSF_Y_DERED"].min()
# Out:
# 17.928144454956055

# %%
vvds[vvds["WAVG_MAG_PSF_Y_DERED"]<90]["WAVG_MAG_PSF_Y_DERED"].max()
# Out:
# 21.414615631103516

# %%
vvds.loc[vvds[feat[0]]==99,feat[0]] = vvds[vvds[feat[0]]!=99][feat[0]].max()
vvds.loc[vvds[feat[1]]==99,feat[1]] = vvds[vvds[feat[1]]!=99][feat[1]].max()
vvds.loc[vvds[feat[2]]==99,feat[2]] = vvds[vvds[feat[2]]!=99][feat[2]].max()
vvds.loc[vvds[feat[3]]==99,feat[3]] = vvds[vvds[feat[3]]!=99][feat[3]].max()
vvds.loc[vvds[feat[4]]==99,feat[4]] = vvds[vvds[feat[4]]!=99][feat[4]].max()

# %%
vvds.loc[vvds[feat[10]]>90,feat[10]] = vvds[vvds[feat[10]]<90][feat[10]].max()
vvds.loc[vvds[feat[11]]>90,feat[11]] = vvds[vvds[feat[11]]<90][feat[11]].max()
vvds.loc[vvds[feat[12]]>90,feat[12]] = vvds[vvds[feat[12]]<90][feat[12]].max()
vvds.loc[vvds[feat[13]]>90,feat[13]] = vvds[vvds[feat[13]]<90][feat[13]].max()
vvds.loc[vvds[feat[14]]>90,feat[14]] = vvds[vvds[feat[14]]<90][feat[14]].max()

# %%
vvds.loc[vvds[feat[15]]>90,feat[15]] = vvds[vvds[feat[15]]<90][feat[15]].max()
vvds.loc[vvds[feat[16]]>90,feat[16]] = vvds[vvds[feat[16]]<90][feat[16]].max()
vvds.loc[vvds[feat[17]]>90,feat[17]] = vvds[vvds[feat[17]]<90][feat[17]].max()
vvds.loc[vvds[feat[18]]>90,feat[18]] = vvds[vvds[feat[18]]<90][feat[18]].max()
vvds.loc[vvds[feat[19]]>90,feat[19]] = vvds[vvds[feat[19]]<90][feat[19]].max()

# %%
for i in feat:
    print(i," is ",100*len(vvds[(vvds[i]==99) | (vvds[i]==-99) | (vvds[i]>90)][i])/len(vvds),"%")
# Out:
# MAG_AUTO_G  is  0.0 %
# MAG_AUTO_R  is  0.0 %
# MAG_AUTO_I  is  0.0 %
# MAG_AUTO_Z  is  0.0 %
# MAG_AUTO_Y  is  0.0 %
# MAG_AUTO_G_DERED  is  0.43684018929741536 %
# MAG_AUTO_R_DERED  is  0.03640334910811795 %
# MAG_AUTO_I_DERED  is  0.03640334910811795 %
# MAG_AUTO_Z_DERED  is  0.1456133964324718 %
# MAG_AUTO_Y_DERED  is  4.659628685839097 %
# WAVG_MAG_PSF_G  is  0.0 %
# WAVG_MAG_PSF_R  is  0.0 %
# WAVG_MAG_PSF_I  is  0.0 %
# WAVG_MAG_PSF_Z  is  0.0 %
# WAVG_MAG_PSF_Y  is  0.0 %
# WAVG_MAG_PSF_G_DERED  is  0.0 %
# WAVG_MAG_PSF_R_DERED  is  0.0 %
# WAVG_MAG_PSF_I_DERED  is  0.0 %
# WAVG_MAG_PSF_Z_DERED  is  0.0 %
# WAVG_MAG_PSF_Y_DERED  is  0.0 %

# %%
vvds.loc[vvds[feat[5]]>90,feat[5]] = vvds[vvds[feat[5]]<90][feat[5]].max()
vvds.loc[vvds[feat[6]]>90,feat[6]] = vvds[vvds[feat[6]]<90][feat[6]].max()
vvds.loc[vvds[feat[7]]>90,feat[7]] = vvds[vvds[feat[7]]<90][feat[7]].max()
vvds.loc[vvds[feat[8]]>90,feat[8]] = vvds[vvds[feat[8]]<90][feat[8]].max()
vvds.loc[vvds[feat[9]]>90,feat[9]] = vvds[vvds[feat[9]]<90][feat[9]].max()

# %%
for i in feat:
    print(i," is ",100*len(vvds[(vvds[i]==99) | (vvds[i]==-99) | (vvds[i]>90)][i])/len(vvds),"%")
# Out:
# MAG_AUTO_G  is  0.0 %
# MAG_AUTO_R  is  0.0 %
# MAG_AUTO_I  is  0.0 %
# MAG_AUTO_Z  is  0.0 %
# MAG_AUTO_Y  is  0.0 %
# MAG_AUTO_G_DERED  is  0.0 %
# MAG_AUTO_R_DERED  is  0.0 %
# MAG_AUTO_I_DERED  is  0.0 %
# MAG_AUTO_Z_DERED  is  0.0 %
# MAG_AUTO_Y_DERED  is  0.0 %
# WAVG_MAG_PSF_G  is  0.0 %
# WAVG_MAG_PSF_R  is  0.0 %
# WAVG_MAG_PSF_I  is  0.0 %
# WAVG_MAG_PSF_Z  is  0.0 %
# WAVG_MAG_PSF_Y  is  0.0 %
# WAVG_MAG_PSF_G_DERED  is  0.0 %
# WAVG_MAG_PSF_R_DERED  is  0.0 %
# WAVG_MAG_PSF_I_DERED  is  0.0 %
# WAVG_MAG_PSF_Z_DERED  is  0.0 %
# WAVG_MAG_PSF_Y_DERED  is  0.0 %

# %%
print("With this choice we maintain",100*(len(vvds)/originalTam),"%")
# Out:
# With this choice we maintain 100.0 %

# %%
count1, n1 = np.histogram(des['MAG_AUTO_R_DERED'],bins = np.linspace(0,30,100))
count2, n2 = np.histogram(vvds['MAG_AUTO_R_DERED'],bins = np.linspace(0,30,100))

# %% [markdown]
# ## Plots

# %%
plt.figure(figsize=(12,10))
plt.bar(n2[:-1],(count2/count1))
plt.xlabel("Object in  MAG_AUTO_R_DERED")
#plt.ylim(0.8)
# Out:
# <ipython-input-51-b96cd0d35c18>:2: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(n2[:-1],(count2/count1))
# Text(0.5, 0, 'Object in  MAG_AUTO_R_DERED')

# %%
feat.append("z")

# %%
plt.figure(figsize=(40,32))
corrmat = vvds[feat].corr()
fig, ax = plt.subplots(figsize=(25,15))         # Sample figsize in inches
sns.heatmap(corrmat,annot=True,cmap="viridis")
plt.tight_layout()

# %%
plt.figure(figsize=(40,24))
correlations =corrmat.abs()['z'].sort_values(ascending=False)[1:]
ax = sns.barplot(x=correlations.values,y=correlations.index).set_title('Most Correlated with Z')
plt.tight_layout()
plt.savefig("correlations.png",dpi = 500,bbox_inches = "tight" )

# %%
feat
# Out:
# ['MAG_AUTO_G',
#  'MAG_AUTO_R',
#  'MAG_AUTO_I',
#  'MAG_AUTO_Z',
#  'MAG_AUTO_Y',
#  'MAG_AUTO_G_DERED',
#  'MAG_AUTO_R_DERED',
#  'MAG_AUTO_I_DERED',
#  'MAG_AUTO_Z_DERED',
#  'MAG_AUTO_Y_DERED',
#  'WAVG_MAG_PSF_G',
#  'WAVG_MAG_PSF_R',
#  'WAVG_MAG_PSF_I',
#  'WAVG_MAG_PSF_Z',
#  'WAVG_MAG_PSF_Y',
#  'WAVG_MAG_PSF_G_DERED',
#  'WAVG_MAG_PSF_R_DERED',
#  'WAVG_MAG_PSF_I_DERED',
#  'WAVG_MAG_PSF_Z_DERED',
#  'WAVG_MAG_PSF_Y_DERED',
#  'z']

# %%
plt.figure(figsize=(16,8))
sns.pairplot(vvds[feat],diag_kind= "kde",corner= True)

# %%
pca_test = PCA(n_components=7)
pca_test.fit(vvds[feat[0:19]])
sns.set(style='whitegrid')
plt.plot(np.cumsum(pca_test.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
#plt.axvline(linewidth=4, color='r', linestyle = '--', x=2, ymin=0, ymax=1)
display(plt.show())
evr = pca_test.explained_variance_ratio_
cvr = np.cumsum(pca_test.explained_variance_ratio_)
pca_df = pd.DataFrame()
pca_df['Cumulative Variance Ratio'] = cvr
pca_df['Explained Variance Ratio'] = evr
display(pca_df.head(10))
# Out:
# None
#    Cumulative Variance Ratio  Explained Variance Ratio
# 0                   0.761966                  0.761966
# 1                   0.911306                  0.149340
# 2                   0.961599                  0.050293
# 3                   0.976880                  0.015281
# 4                   0.984396                  0.007517
# 5                   0.990343                  0.005947
# 6                   0.993998                  0.003654

# %%
pca = PCA(n_components=5)
new_feat = pca.fit_transform(vvds[feat[0:19]])
new_components = pd.DataFrame(new_feat,columns=["1 Component","2 Component","3 Component","4 Component","5 Component"])
new_components["z"] = vvds["z"]
new_components.head()
# Out:
#    1 Component  2 Component  3 Component  4 Component  5 Component      z
# 0     2.079763     0.369875    -0.192067    -0.180945    -0.410451  0.871
# 1     3.926401    -0.559011     1.122159    -0.080336     0.317874  0.382
# 2     3.166584     0.804097    -0.662130     0.612486    -0.215836  0.266
# 3     2.656694     1.335605    -1.011323    -0.189602    -0.149884  0.244
# 4     3.760201    -0.206702     1.631157     0.525082     0.520567  0.519

# %%
plt.figure(figsize=(16,12))
corrmat1 = new_components.corr()
fig, ax = plt.subplots(figsize=(25,15))         # Sample figsize in inches
sns.heatmap(corrmat1,annot=True,cmap="viridis")
plt.tight_layout()

# %%
plt.figure(figsize=(18,12))
correlations =corrmat1.abs()['z'].sort_values(ascending=False)[1:]
ax = sns.barplot(x=correlations.values,y=correlations.index).set_title('Most Correlated with Z')
plt.tight_layout()

# %%
plt.figure(figsize=(16,8))
sns.pairplot(new_components,diag_kind= "kde",corner= True)

# %% [markdown]
# ## Machine Learning

# %%
X,y = get_features_targets2(vvds)

# %%
X_train,X_test,y_train,y_test = tts_split(X,y,0.3)

# %%
X = np.concatenate((X,vvds["MAG_AUTO_I_DERED"].values.reshape(-1,1)),axis = 1)

# %%
EarlyStop = EarlyStopping(monitor='rmse_ann', mode='min', patience=15)
n_inputs = X_train.shape[1]

# %%
ann_model = Sequential([Dense(n_inputs,input_shape = X_train.shape[1:],kernel_initializer='normal', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)),
                       Dropout(0.45),
                       Dense(10, kernel_initializer='normal', activation='tanh',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)),
                       Dropout(0.45),
                       Dense(10,kernel_initializer='normal', activation='tanh',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)) ,
                       Dense(1,activation = None,name = "output")
                       ])
opt = ks.optimizers.Adam(lr=0.001, decay=5e-4)
#opt = tf.keras.optimizers.RMSprop(0.001)
ann_model.compile(optimizer=opt, loss=rmse_ann, metrics=['mse', 'mae', 'mape',rmse_ann])

# %%
history = ann_model.fit(X_train, y_train, epochs=512,batch_size=64, validation_split=0.2, callbacks=[EarlyStop])
# Out:
# Epoch 1/512
# 25/25 [==============================] - 1s 17ms/step - loss: 0.5934 - mse: 0.4322 - mae: 0.5933 - mape: 197638.1017 - rmse_ann: 0.5933 - val_loss: 0.4704 - val_mse: 0.3047 - val_mae: 0.4703 - val_mape: 1992682.5000 - val_rmse_ann: 0.4703
# Epoch 2/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3886 - mse: 0.2249 - mae: 0.3885 - mape: 912177.2640 - rmse_ann: 0.3885 - val_loss: 0.2535 - val_mse: 0.1078 - val_mae: 0.2533 - val_mape: 6122117.0000 - val_rmse_ann: 0.2533
# Epoch 3/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2577 - mse: 0.1207 - mae: 0.2575 - mape: 1933976.5483 - rmse_ann: 0.2575 - val_loss: 0.2339 - val_mse: 0.0935 - val_mae: 0.2337 - val_mape: 6891501.5000 - val_rmse_ann: 0.2337
# Epoch 4/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2433 - mse: 0.0978 - mae: 0.2431 - mape: 3183435.3816 - rmse_ann: 0.2431 - val_loss: 0.2319 - val_mse: 0.0919 - val_mae: 0.2317 - val_mape: 6689196.0000 - val_rmse_ann: 0.2317
# Epoch 5/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2340 - mse: 0.0883 - mae: 0.2338 - mape: 4514056.6058 - rmse_ann: 0.2338 - val_loss: 0.2294 - val_mse: 0.0903 - val_mae: 0.2292 - val_mape: 6677986.5000 - val_rmse_ann: 0.2292
# Epoch 6/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2393 - mse: 0.0913 - mae: 0.2391 - mape: 2711102.0693 - rmse_ann: 0.2391 - val_loss: 0.2265 - val_mse: 0.0884 - val_mae: 0.2263 - val_mape: 6714372.5000 - val_rmse_ann: 0.2263
# Epoch 7/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2232 - mse: 0.0799 - mae: 0.2230 - mape: 4402856.1731 - rmse_ann: 0.2230 - val_loss: 0.2227 - val_mse: 0.0866 - val_mae: 0.2225 - val_mape: 6853879.5000 - val_rmse_ann: 0.2225
# Epoch 8/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2244 - mse: 0.0906 - mae: 0.2242 - mape: 2762277.3509 - rmse_ann: 0.2242 - val_loss: 0.2241 - val_mse: 0.0870 - val_mae: 0.2239 - val_mape: 6653998.0000 - val_rmse_ann: 0.2239
# Epoch 9/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2207 - mse: 0.0865 - mae: 0.2205 - mape: 2059285.1527 - rmse_ann: 0.2205 - val_loss: 0.2197 - val_mse: 0.0850 - val_mae: 0.2195 - val_mape: 6776344.0000 - val_rmse_ann: 0.2195
# Epoch 10/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2243 - mse: 0.0900 - mae: 0.2241 - mape: 2449605.5030 - rmse_ann: 0.2241 - val_loss: 0.2173 - val_mse: 0.0838 - val_mae: 0.2171 - val_mape: 6743166.5000 - val_rmse_ann: 0.2171
# Epoch 11/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2050 - mse: 0.0724 - mae: 0.2047 - mape: 2569299.0982 - rmse_ann: 0.2047 - val_loss: 0.2138 - val_mse: 0.0822 - val_mae: 0.2136 - val_mape: 6735372.5000 - val_rmse_ann: 0.2136
# Epoch 12/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2109 - mse: 0.0837 - mae: 0.2107 - mape: 3467450.4035 - rmse_ann: 0.2107 - val_loss: 0.2128 - val_mse: 0.0813 - val_mae: 0.2126 - val_mape: 6613911.0000 - val_rmse_ann: 0.2126
# Epoch 13/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2115 - mse: 0.0811 - mae: 0.2113 - mape: 2033853.4773 - rmse_ann: 0.2113 - val_loss: 0.2065 - val_mse: 0.0787 - val_mae: 0.2063 - val_mape: 6809826.0000 - val_rmse_ann: 0.2063
# Epoch 14/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2172 - mse: 0.0898 - mae: 0.2169 - mape: 4108471.6010 - rmse_ann: 0.2169 - val_loss: 0.2077 - val_mse: 0.0790 - val_mae: 0.2074 - val_mape: 6440073.0000 - val_rmse_ann: 0.2074
# Epoch 15/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2028 - mse: 0.0707 - mae: 0.2025 - mape: 2050470.3865 - rmse_ann: 0.2025 - val_loss: 0.1992 - val_mse: 0.0755 - val_mae: 0.1989 - val_mape: 6670005.0000 - val_rmse_ann: 0.1989
# Epoch 16/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2028 - mse: 0.0734 - mae: 0.2025 - mape: 2503765.3104 - rmse_ann: 0.2025 - val_loss: 0.1989 - val_mse: 0.0755 - val_mae: 0.1987 - val_mape: 6424960.5000 - val_rmse_ann: 0.1987
# Epoch 17/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1986 - mse: 0.0673 - mae: 0.1983 - mape: 2098737.8350 - rmse_ann: 0.1983 - val_loss: 0.1965 - val_mse: 0.0746 - val_mae: 0.1962 - val_mape: 6467168.5000 - val_rmse_ann: 0.1962
# Epoch 18/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1945 - mse: 0.0716 - mae: 0.1942 - mape: 2226819.4215 - rmse_ann: 0.1942 - val_loss: 0.1938 - val_mse: 0.0738 - val_mae: 0.1935 - val_mape: 6556496.5000 - val_rmse_ann: 0.1935
# Epoch 19/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1837 - mse: 0.0608 - mae: 0.1834 - mape: 3218913.7885 - rmse_ann: 0.1834 - val_loss: 0.1932 - val_mse: 0.0739 - val_mae: 0.1929 - val_mape: 6454564.5000 - val_rmse_ann: 0.1929
# Epoch 20/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1981 - mse: 0.0717 - mae: 0.1978 - mape: 2036058.8487 - rmse_ann: 0.1978 - val_loss: 0.1939 - val_mse: 0.0742 - val_mae: 0.1936 - val_mape: 6378743.5000 - val_rmse_ann: 0.1936
# Epoch 21/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1930 - mse: 0.0763 - mae: 0.1927 - mape: 3474260.5512 - rmse_ann: 0.1927 - val_loss: 0.1921 - val_mse: 0.0737 - val_mae: 0.1918 - val_mape: 6490962.0000 - val_rmse_ann: 0.1918
# Epoch 22/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1923 - mse: 0.0708 - mae: 0.1920 - mape: 1563249.9028 - rmse_ann: 0.1920 - val_loss: 0.1919 - val_mse: 0.0737 - val_mae: 0.1916 - val_mape: 6501110.0000 - val_rmse_ann: 0.1916
# Epoch 23/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1933 - mse: 0.0844 - mae: 0.1930 - mape: 2069276.2671 - rmse_ann: 0.1930 - val_loss: 0.1923 - val_mse: 0.0738 - val_mae: 0.1920 - val_mape: 6393626.0000 - val_rmse_ann: 0.1920
# Epoch 24/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1863 - mse: 0.0668 - mae: 0.1859 - mape: 2937352.5679 - rmse_ann: 0.1859 - val_loss: 0.1902 - val_mse: 0.0731 - val_mae: 0.1899 - val_mape: 6555309.0000 - val_rmse_ann: 0.1899
# Epoch 25/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1973 - mse: 0.0792 - mae: 0.1970 - mape: 3903943.6442 - rmse_ann: 0.1970 - val_loss: 0.1915 - val_mse: 0.0738 - val_mae: 0.1912 - val_mape: 6357699.5000 - val_rmse_ann: 0.1912
# Epoch 26/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1835 - mse: 0.0638 - mae: 0.1832 - mape: 3099882.7981 - rmse_ann: 0.1832 - val_loss: 0.1915 - val_mse: 0.0738 - val_mae: 0.1912 - val_mape: 6388854.5000 - val_rmse_ann: 0.1912
# Epoch 27/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1891 - mse: 0.0674 - mae: 0.1888 - mape: 2283113.2812 - rmse_ann: 0.1888 - val_loss: 0.1915 - val_mse: 0.0739 - val_mae: 0.1912 - val_mape: 6303859.5000 - val_rmse_ann: 0.1912
# Epoch 28/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1946 - mse: 0.0746 - mae: 0.1943 - mape: 2118433.8245 - rmse_ann: 0.1943 - val_loss: 0.1933 - val_mse: 0.0745 - val_mae: 0.1930 - val_mape: 6225638.5000 - val_rmse_ann: 0.1930
# Epoch 29/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1831 - mse: 0.0612 - mae: 0.1828 - mape: 2009553.3874 - rmse_ann: 0.1828 - val_loss: 0.1918 - val_mse: 0.0736 - val_mae: 0.1915 - val_mape: 6454277.5000 - val_rmse_ann: 0.1915
# Epoch 30/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1886 - mse: 0.0669 - mae: 0.1883 - mape: 971431.4940 - rmse_ann: 0.1883 - val_loss: 0.1941 - val_mse: 0.0746 - val_mae: 0.1938 - val_mape: 6275780.0000 - val_rmse_ann: 0.1938
# Epoch 31/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1896 - mse: 0.0677 - mae: 0.1893 - mape: 2340381.5366 - rmse_ann: 0.1893 - val_loss: 0.1912 - val_mse: 0.0734 - val_mae: 0.1909 - val_mape: 6574929.0000 - val_rmse_ann: 0.1909
# Epoch 32/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1881 - mse: 0.0667 - mae: 0.1878 - mape: 2472515.5048 - rmse_ann: 0.1878 - val_loss: 0.1927 - val_mse: 0.0741 - val_mae: 0.1924 - val_mape: 6329120.0000 - val_rmse_ann: 0.1924
# Epoch 33/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1949 - mse: 0.0779 - mae: 0.1946 - mape: 3285052.4327 - rmse_ann: 0.1946 - val_loss: 0.1915 - val_mse: 0.0736 - val_mae: 0.1912 - val_mape: 6405221.0000 - val_rmse_ann: 0.1912
# Epoch 34/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1952 - mse: 0.0782 - mae: 0.1949 - mape: 3943617.3654 - rmse_ann: 0.1949 - val_loss: 0.1924 - val_mse: 0.0740 - val_mae: 0.1921 - val_mape: 6341148.5000 - val_rmse_ann: 0.1921
# Epoch 35/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1871 - mse: 0.0654 - mae: 0.1868 - mape: 1410611.2628 - rmse_ann: 0.1868 - val_loss: 0.1915 - val_mse: 0.0736 - val_mae: 0.1912 - val_mape: 6433084.5000 - val_rmse_ann: 0.1912
# Epoch 36/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1913 - mse: 0.0824 - mae: 0.1910 - mape: 2815685.1848 - rmse_ann: 0.1910 - val_loss: 0.1919 - val_mse: 0.0738 - val_mae: 0.1916 - val_mape: 6390957.5000 - val_rmse_ann: 0.1916
# Epoch 37/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1835 - mse: 0.0676 - mae: 0.1832 - mape: 2893448.2067 - rmse_ann: 0.1832 - val_loss: 0.1920 - val_mse: 0.0737 - val_mae: 0.1917 - val_mape: 6508942.5000 - val_rmse_ann: 0.1917
# Epoch 38/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1869 - mse: 0.0634 - mae: 0.1866 - mape: 3463176.2692 - rmse_ann: 0.1866 - val_loss: 0.1925 - val_mse: 0.0740 - val_mae: 0.1922 - val_mape: 6464207.5000 - val_rmse_ann: 0.1922
# Epoch 39/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1961 - mse: 0.0729 - mae: 0.1958 - mape: 2719472.9692 - rmse_ann: 0.1958 - val_loss: 0.1929 - val_mse: 0.0742 - val_mae: 0.1926 - val_mape: 6401433.0000 - val_rmse_ann: 0.1926
# Epoch 40/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1803 - mse: 0.0631 - mae: 0.1800 - mape: 1824005.9649 - rmse_ann: 0.1800 - val_loss: 0.1918 - val_mse: 0.0737 - val_mae: 0.1915 - val_mape: 6437210.0000 - val_rmse_ann: 0.1915
# Epoch 41/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1840 - mse: 0.0629 - mae: 0.1837 - mape: 2187207.6728 - rmse_ann: 0.1837 - val_loss: 0.1921 - val_mse: 0.0738 - val_mae: 0.1918 - val_mape: 6410280.0000 - val_rmse_ann: 0.1918
# Epoch 42/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1770 - mse: 0.0593 - mae: 0.1767 - mape: 1296119.6029 - rmse_ann: 0.1767 - val_loss: 0.1921 - val_mse: 0.0738 - val_mae: 0.1918 - val_mape: 6389784.0000 - val_rmse_ann: 0.1918
# Epoch 43/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1886 - mse: 0.0643 - mae: 0.1883 - mape: 2902023.3413 - rmse_ann: 0.1883 - val_loss: 0.1913 - val_mse: 0.0735 - val_mae: 0.1910 - val_mape: 6540100.0000 - val_rmse_ann: 0.1910
# Epoch 44/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1799 - mse: 0.0624 - mae: 0.1796 - mape: 2029525.5483 - rmse_ann: 0.1796 - val_loss: 0.1928 - val_mse: 0.0742 - val_mae: 0.1925 - val_mape: 6376307.0000 - val_rmse_ann: 0.1925
# Epoch 45/512
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1793 - mse: 0.0650 - mae: 0.1790 - mape: 3386486.4470 - rmse_ann: 0.1790 - val_loss: 0.1921 - val_mse: 0.0738 - val_mae: 0.1918 - val_mape: 6408842.5000 - val_rmse_ann: 0.1918
# Epoch 46/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1794 - mse: 0.0586 - mae: 0.1791 - mape: 1427669.3599 - rmse_ann: 0.1791 - val_loss: 0.1910 - val_mse: 0.0735 - val_mae: 0.1907 - val_mape: 6412175.0000 - val_rmse_ann: 0.1907
# Epoch 47/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1931 - mse: 0.0746 - mae: 0.1928 - mape: 2037910.0455 - rmse_ann: 0.1928 - val_loss: 0.1914 - val_mse: 0.0737 - val_mae: 0.1911 - val_mape: 6410029.0000 - val_rmse_ann: 0.1911
# Epoch 48/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1906 - mse: 0.0754 - mae: 0.1902 - mape: 3226570.8510 - rmse_ann: 0.1902 - val_loss: 0.1916 - val_mse: 0.0737 - val_mae: 0.1913 - val_mape: 6407863.5000 - val_rmse_ann: 0.1913
# Epoch 49/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1859 - mse: 0.0643 - mae: 0.1856 - mape: 2486663.7098 - rmse_ann: 0.1856 - val_loss: 0.1910 - val_mse: 0.0733 - val_mae: 0.1907 - val_mape: 6615197.5000 - val_rmse_ann: 0.1907
# Epoch 50/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1864 - mse: 0.0640 - mae: 0.1861 - mape: 3125409.5145 - rmse_ann: 0.1861 - val_loss: 0.1927 - val_mse: 0.0742 - val_mae: 0.1924 - val_mape: 6409355.0000 - val_rmse_ann: 0.1924
# Epoch 51/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1895 - mse: 0.0720 - mae: 0.1892 - mape: 2862465.2498 - rmse_ann: 0.1892 - val_loss: 0.1929 - val_mse: 0.0739 - val_mae: 0.1926 - val_mape: 6493315.5000 - val_rmse_ann: 0.1926
# Epoch 52/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1918 - mse: 0.0727 - mae: 0.1915 - mape: 2707884.1909 - rmse_ann: 0.1915 - val_loss: 0.1921 - val_mse: 0.0737 - val_mae: 0.1918 - val_mape: 6510251.5000 - val_rmse_ann: 0.1918
# Epoch 53/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1961 - mse: 0.0745 - mae: 0.1958 - mape: 2867406.4320 - rmse_ann: 0.1958 - val_loss: 0.1920 - val_mse: 0.0740 - val_mae: 0.1917 - val_mape: 6372725.5000 - val_rmse_ann: 0.1917
# Epoch 54/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1920 - mse: 0.0669 - mae: 0.1917 - mape: 2323058.6004 - rmse_ann: 0.1917 - val_loss: 0.1920 - val_mse: 0.0740 - val_mae: 0.1917 - val_mape: 6344198.5000 - val_rmse_ann: 0.1917
# Epoch 55/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1870 - mse: 0.0683 - mae: 0.1867 - mape: 3540186.7463 - rmse_ann: 0.1867 - val_loss: 0.1907 - val_mse: 0.0734 - val_mae: 0.1904 - val_mape: 6529360.0000 - val_rmse_ann: 0.1904
# Epoch 56/512
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1864 - mse: 0.0660 - mae: 0.1861 - mape: 1972059.6218 - rmse_ann: 0.1861 - val_loss: 0.1904 - val_mse: 0.0734 - val_mae: 0.1901 - val_mape: 6509073.5000 - val_rmse_ann: 0.1901

# %%
plot_history(history)

# %%
loss, mae, mse,mape,rmse_ann = ann_model.evaluate(X_test, y_test)

print("Testing set Mean Abs Error: {:5.2f} ".format(mae))
print("\n")
print("Testing set Root Mean Abs Error: {:5.2f} ".format(rmse_ann))
# Out:
# 26/26 [==============================] - 0s 806us/step - loss: 0.1818 - mse: 0.0678 - mae: 0.1815 - mape: 3118277.7500 - rmse_ann: 0.1815
# Testing set Mean Abs Error:  0.07
#
#
# Testing set Root Mean Abs Error:  0.18

# %%
test_predictions = ann_model.predict(X_test).flatten()

plt.figure(figsize=(16,8))
plt.scatter(y_test, test_predictions,s=10)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
plt.figure(figsize=(16,8))
plt.hist(test_predictions,bins = 50)
plt.xlabel('Predictions')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Stacked Method

# %%
from ml_functions import AveragingModels
def build_nn():

    ann_model = Sequential([Dense(n_inputs,input_shape = X_train.shape[1:],kernel_initializer='normal', activation='relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)),
                       Dropout(0.05),
                       Dense(10, kernel_initializer='normal', activation='tanh',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)),
                       Dropout(0.45),
                       Dense(10,kernel_initializer='normal', activation='tanh',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                              bias_regularizer=regularizers.l2(1e-4),activity_regularizer=regularizers.l2(1e-5)) ,
                       Dense(1,activation = None,name = "output")
                       ])
    opt = ks.optimizers.Adam(lr=0.001, decay=5e-4)
    #opt = tf.keras.optimizers.RMSprop(0.001)
    ann_model.compile(optimizer=opt, loss=rmse_ann2, metrics=['mse', 'mae', 'mape',rmse_ann2])
    
    return ann_model

DTR_boost = AdaBoostRegressor(base_estimator= DecisionTreeRegressor(max_depth=10, min_samples_split=30, splitter='random'),
                             learning_rate=0.01, loss='exponential', n_estimators=200)
DTR_bag = BaggingRegressor(base_estimator=DecisionTreeRegressor(max_depth=10, min_samples_split=30, splitter='random'),n_estimators=200)

models = [AdaBoostRegressor(base_estimator=GradientBoostingRegressor(criterion='mae',
                                                            loss='lad',
                                                            max_features='log2',
                                                            n_estimators=200),
                   learning_rate=0.01, loss='exponential', n_estimators=200),
 BaggingRegressor(base_estimator=RandomForestRegressor(criterion='mae',
                                                       max_depth=13,
                                                       min_samples_split=20),
                  n_estimators=200, n_jobs=-1),DTR_boost,DTR_bag]
ann1_clf = tf.keras.wrappers.scikit_learn.KerasRegressor(
                            build_nn,
                            epochs=200,batch_size=64,validation_split=0.2,
                            verbose=False)
ann1_clf._estimator_type = 'regressor'

# %%
averaged_models = AveragingModels(models = (models[0], models[1], models[2], ann1_clf))

# %%
averaged_models.fit(X_train,y_train)

# %%
pred_averaged_models = averaged_models.predict(X_test)

# %%
print(" Averaged base models score: ROOT MAE {:.4f} MAE ({:.4f})\n".format(rmsle(pred_averaged_models,y_test), mean_squared_error(pred_averaged_models,y_test)))

# %%
test_predictions = pred_averaged_models

plt.figure(figsize=(16,8))
plt.scatter(y_test, test_predictions,s=10)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
plt.figure(figsize=(16,8))
plt.hist(test_predictions,bins = 50)
plt.title("Predictions Histogram")
plt.xlabel('Predictions')
plt.ylabel('Frequency')

# %%
from ml_functions import StackingAveragedModels

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (models[0], models[1], models[2], ann1_clf),
                                                 meta_model = models[3],n_folds = 3)

# %%
stacked_averaged_models.fit(X_train,y_train)

# %%
pred_stacked = stacked_averaged_models.predict(X_test)

# %%
print(" Averaged base models score: ROOT MAE {:.4f} MAE ({:.4f})\n".format(rmsle(pred_stacked,y_test), mean_squared_error(pred_stacked,y_test)))

# %%
test_predictions = pred_stacked

plt.figure(figsize=(16,8))
plt.scatter(y_test, test_predictions,s=10)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
plt.figure(figsize=(16,8))
plt.hist(test_predictions,bins = 50)
plt.title("Predictions Histogram")
plt.xlabel('Predictions')
plt.ylabel('Frequency')
